# %%
# Q1
l = []
i = 0
while (i<=5):
  l.append(i)
  i+=1

print(l)

l2 = list(range(1, 10, 2))
print(l2)

# Q2
l2.extend(range(11, 20, 2))
l2.insert(2, 20)
print(l2)
l2.append(1)
l2.remove(1)
print(l2)
l2.pop()
print(l2)
i = 0
while i<5:
  l2.append(5)
  i+=1
print(l2.index(5))
l2.count(5)
print(l2)
l2.sort()
print(l2)
l2.reverse()
print(l2)
l2.count(5)
print(l2)
l = l2.copy()

l2.append("Oink")
print(l2)
print(l, "Shallow copy of l2, prior to insertion of 'Oink'")

print("\n\n\n")


# Bonus Q1
input_str = input("Enter input for string: \t")
input_int = int(input("Enter input for integer: \t"))

# Bonus Q2
print("The inputs were-\n\tFor String:\t{}\n\tFor Integer:\t{}".format(input_str, input_int))

# Bonus Q3
num_comp1 = complex(10, 2)
num_comp2 = complex(10, 5)
print(f"Square of {num_comp1}:\t\t{num_comp1*num_comp1}\nProduct of {num_comp1} and {num_comp2}:\t{num_comp1*num_comp2}")

boolean = True
print(type(boolean))

print(f"Working on '{input_str}")


# Topics to be covered in today's session
for i in input_str[::-2]:
  print(i)

tup = ("This", "is", "a", "tuple")                        # a list, but immutable
s = {"This", "is", "a", "set", "hehe", tup}               # unordered data type: Also worth noting, you cannot add a list (mutable data) in a set, but tuple is acceptable
dic = {"Key":"Value",
       "Pair":"Something",
       "keys has to be immutable":"Values can be mutable",
       tup:["Hello", 15, 16]
       }

print()
for ele in dic:
  print(ele, dic[ele], sep="\t")
